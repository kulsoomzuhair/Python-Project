# %% [markdown]
# # Data Processing Before Mapping and Graph
# >**Steps of preprocessing of data**
# *  Import necessary library
# *  Read Dataset
# *  Sanity check of data
# *  Exploratory Data Analysis(EDA)
# *  Missing Value treatments
# *  Outliers treatments
# *  duplicates & garbage value treatments
# *  Normalization
# *  Encoding of data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset= pd.read_csv(r"C:\Users\kulso\Documents\Dashboards-Projects\pythonProjects\Ice Cream Ratings.csv")
dataset.set_index('Date')
# Out:
#           Flavor Rating  Texture Rating  Overall Rating
# Date
# 1/1/2022       0.223090        0.040220        0.600129
# 1/2/2022       0.635886        0.938476        0.106264
# 1/3/2022       0.442323        0.044154        0.598112
# 1/4/2022       0.389128        0.549676        0.489353
# 1/5/2022       0.386887        0.519439        0.988280
# 1/6/2022       0.877984        0.193588        0.832827
# 1/7/2022       0.140995        0.325110        0.105147

# %%
dataset.plot(kind='line',title ='Ice Cream Rating' , xlabel='Daily Rating', ylabel='Scores')
# Out:
# <Axes: title={'center': 'Ice Cream Rating'}, xlabel='Daily Rating', ylabel='Scores'>

# %%
dataset.plot.barh( stacked=True)
# Out:
# <Axes: >

# %%
dataset.plot.scatter( x='Texture Rating',y='Overall Rating', s=120,c='red')
# Out:
# <Axes: xlabel='Texture Rating', ylabel='Overall Rating'>

# %%
dataset.plot.hist(bins=100, figsize = (5,3))
# Out:
# <Axes: ylabel='Frequency'>

# %%
dataset.boxplot()
# Out:
# <Axes: >

# %%
dataset.plot.area(figsize = (10,5), xlabel='Date')
# Out:
# <Axes: xlabel='Date'>

# %%
dataset.plot.pie(y='Flavor Rating',figsize=(10,5))
plt.style.use('seaborn-v0_8-deep')
